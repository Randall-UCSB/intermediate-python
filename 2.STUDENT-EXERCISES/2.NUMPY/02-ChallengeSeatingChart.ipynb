# %% [markdown]
# ## Challenge: Working with a NumPy Matrix
# ### NumPy Seating Chart (3.7)

# %% [markdown]
# - This challenge exercise is based on:
#
# ### Key concepts
# - Creating and ndarrays
# - Working with both 1D and 2D arrays
# - Using built-in functions on ndarrays
# - Indexing
# - Accessing, deleting, and inserting elements into ndarrays
#
# ### Specific Skills and Knowlege
# - Modify an element of 1-D array
# - Access individual elements of 2-D array
# - Modify an element of 2-D array
# - numpy.delete()
# - numpy.append()
# - numpy.insert()
# - numpy.hstack()
# - numpy.vstack()

# %% [markdown]
# ### Instructions
#
# You're managing seating for a small theater. Each seat is represented by a number in a NumPy array:
# - 0 means the seat is empty
# - 1 means the seat is taken
#
# You'll perform modifications to simulate ticket sales, cancellations, and re-arrangements.
#
# 1. Create a 1D NumPy array called row with 5 seats, all empty ([0, 0, 0, 0, 0]).
# 2. Mark the third seat as taken (set to 1).
# 3. Create a 2D array theater with 2 identical rows using np.vstack.
# 4. Access and print the seat in row 1, column 3 (using 0-based indexing).
# 5. Modify that seat to be taken (1).
# 6. Delete the last seat in each row (simulate a broken seat).
# 7. Append a new row at the bottom with all empty seats (same length as current rows).
# 8. Insert a new seat (value 0) in the second row at position 2.
# 9. Horizontally stack another row of [1, 1, 1] to each row (simulate VIP seats being added).

# %% [markdown]
# ### Setup

# %%
import numpy as np

# %% [markdown]
# ## Step 1: Create a single row of 5 empty seats

# %% [markdown]
# ##### Step 3: Create a 2D theater with 2 identical rows

# %% [markdown]
# ##### Step 4: Access the seat in row 1, column 3 (use 0-based indexing)

# %% [markdown]
# ##### tep 5: Modify that seat to be taken

# %% [markdown]
# ##### Step 6: Delete the last seat in each row

# %% [markdown]
# ##### Step 7: Append a new empty row at the bottom

# %% [markdown]
# ##### Step 8: Insert a new empty seat (0) in the second row at position 2

# %% [markdown]
# ##### Step 9: Add VIP seats (value 1) to the right side of each row

# %% [markdown]
# ##### Step 10: 🎨 Visualize the final seating chart
#
# gray_r colormap makes 0 = white (empty), 1 = black (taken).
#
# imshow() visualizes the array as a grid.
